# %%
# General libraries
import os
import numpy as np
import pandas as pd 
import random
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# Deep learning libraries
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, InputLayer
from keras.models import Sequential
from keras import optimizers
import keras.backend as K
from keras.models import Model, Sequential
from keras.layers import Input, Dense, Flatten, Dropout, BatchNormalization
from keras.layers import Conv2D, SeparableConv2D, MaxPool2D, LeakyReLU, Activation
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
import tensorflow as tf
from keras.applications.vgg16 import VGG16
# Setting seeds for reproducibility
seed = 232
np.random.seed(seed)
#tf.set_random_seed(seed)

# %%
# Distribution of our datasets

input_path = 'G:/pgdba study material/sem2/dsl/Predicitng-Lungs-Disease--master/chest_xray/normal_Vs_Pneumonia/'
for _set in ['trains', 'tests']:
    n_normal = len(os.listdir(input_path + _set + '/NORMAL'))
    n_infect = len(os.listdir(input_path + _set + '/PNEUMONIA'))
    print('Set: {}, normal images: {}, pneumonia images: {}'.format(_set, n_normal, n_infect))
# Out:
# Set: trains, normal images: 1341, pneumonia images: 1345
# Set: tests, normal images: 234, pneumonia images: 390

# %%
# input_path = '../input/chest_xray/chest_xray/'
input_path = 'G:/pgdba study material/sem2/dsl/Predicitng-Lungs-Disease--master/chest_xray/normal_Vs_Pneumonia/'

def process_data(img_dims, batch_size):
    # Data generation objects
    train_datagen = ImageDataGenerator(rescale=1./255, zoom_range=0.3, vertical_flip=True)
    test_val_datagen = ImageDataGenerator(rescale=1./255)
    
    # This is fed to the network in the specified batch sizes and image dimensions
    train_gen = train_datagen.flow_from_directory(
    directory=input_path+'trains', 
    target_size=(img_dims, img_dims), 
    batch_size=batch_size, 
    class_mode='binary', 
    shuffle=True)

    test_gen = test_val_datagen.flow_from_directory(
    directory=input_path+'tests', 
    target_size=(img_dims, img_dims), 
    batch_size=batch_size, 
    class_mode='binary', 
    shuffle=True)
    
    # I will be making predictions off of the test set in one batch size
    # This is useful to be able to get the confusion matrix
    test_data = []
    test_labels = []

    for cond in ['/NORMAL/', '/PNEUMONIA/']:
        for img in (os.listdir(input_path + 'tests' + cond)):
            img = plt.imread(input_path+'tests'+cond+img)
            img = cv2.resize(img, (img_dims, img_dims))
            img = np.dstack([img, img, img])
            img = img.astype('float32') / 255
            if cond=='/NORMAL/':
                label = 0
            elif cond=='/PNEUMONIA/':
                label = 1
            test_data.append(img)
            test_labels.append(label)
        
    test_data = np.array(test_data)
    test_labels = np.array(test_labels)
    
    return train_gen, test_gen, test_data, test_labels

# %%
# Hyperparameters
img_dims = 224
epochs = 50
batch_size = 32

# Getting the data
train_gen, test_gen, test_data, test_labels = process_data(img_dims, batch_size)
# Out:
# Found 2686 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %%
# Input layer
inputs = Input(shape=(img_dims, img_dims, 3))

# First conv block
x = Conv2D(filters=16, kernel_size=(3, 3), activation='relu', padding='same')(inputs)
x = Conv2D(filters=16, kernel_size=(3, 3), activation='relu', padding='same')(x)
x = MaxPool2D(pool_size=(2, 2))(x)

# Second conv block
x = SeparableConv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='same')(x)
x = SeparableConv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPool2D(pool_size=(2, 2))(x)

# Third conv block
x = SeparableConv2D(filters=64, kernel_size=(3, 3), activation='relu', padding='same')(x)
x = SeparableConv2D(filters=64, kernel_size=(3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPool2D(pool_size=(2, 2))(x)

# Fourth conv block
x = SeparableConv2D(filters=128, kernel_size=(3, 3), activation='relu', padding='same')(x)
x = SeparableConv2D(filters=128, kernel_size=(3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPool2D(pool_size=(2, 2))(x)
x = Dropout(rate=0.2)(x)

# Fifth conv block
x = SeparableConv2D(filters=256, kernel_size=(3, 3), activation='relu', padding='same')(x)
x = SeparableConv2D(filters=256, kernel_size=(3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPool2D(pool_size=(2, 2))(x)
x = Dropout(rate=0.2)(x)


# FC layer
x = Flatten()(x)
x = Dense(units=512, activation='relu')(x)
x = Dropout(rate=0.7)(x)
x = Dense(units=128, activation='relu')(x)
x = Dropout(rate=0.5)(x)
x = Dense(units=64, activation='relu')(x)
x = Dropout(rate=0.3)(x)

# Output layer
output = Dense(units=1, activation='sigmoid')(x)

# Creating model and compiling
model = Model(inputs=inputs, outputs=output)
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Callbacks
checkpoint = ModelCheckpoint(filepath='best_weights.hdf5', save_best_only=True, save_weights_only=True)
lr_reduce = ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=2, verbose=2, mode='max')
early_stop = EarlyStopping(monitor='val_loss', min_delta=0.1, patience=1, mode='min')
# Out:
# WARNING:tensorflow:Large dropout rate: 0.7 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.

# %%
hist = model.fit_generator(
           train_gen, steps_per_epoch=train_gen.samples // batch_size, 
           epochs=epochs, validation_data=test_gen, 
           validation_steps=test_gen.samples // batch_size, callbacks=[checkpoint, lr_reduce])
# Out:
# Epoch 1/50
# 163/163 [==============================] - 465s 3s/step - loss: 0.3648 - accuracy: 0.8301 - val_loss: 0.6781 - val_accuracy: 0.6234
# Epoch 2/50
# 163/163 [==============================] - 480s 3s/step - loss: 0.2917 - accuracy: 0.8765 - val_loss: 1.2980 - val_accuracy: 0.6233
# Epoch 3/50
# 163/163 [==============================] - 390s 2s/step - loss: 0.2448 - accuracy: 0.9003 - val_loss: 2.2406 - val_accuracy: 0.6351
# Epoch 4/50
# 163/163 [==============================] - 407s 2s/step - loss: 0.2390 - accuracy: 0.9066 - val_loss: 0.9838 - val_accuracy: 0.6250
# Epoch 5/50
# 163/163 [==============================] - 382s 2s/step - loss: 0.2104 - accuracy: 0.9201 - val_loss: 0.8424 - val_accuracy: 0.3834
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# Epoch 6/50
# 163/163 [==============================] - 379s 2s/step - loss: 0.1722 - accuracy: 0.9356 - val_loss: 1.2175 - val_accuracy: 0.6132
# Epoch 7/50
# 163/163 [==============================] - 392s 2s/step - loss: 0.1486 - accuracy: 0.9450 - val_loss: 0.7897 - val_accuracy: 0.6655
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# Epoch 8/50
# 163/163 [==============================] - 366s 2s/step - loss: 0.1303 - accuracy: 0.9548 - val_loss: 0.2937 - val_accuracy: 0.8885
# Epoch 9/50
# 163/163 [==============================] - 363s 2s/step - loss: 0.1252 - accuracy: 0.9530 - val_loss: 0.4755 - val_accuracy: 0.8750
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# Epoch 10/50
# 163/163 [==============================] - 375s 2s/step - loss: 0.1265 - accuracy: 0.9530 - val_loss: 0.1891 - val_accuracy: 0.8885
# Epoch 11/50
# 163/163 [==============================] - 396s 2s/step - loss: 0.1235 - accuracy: 0.9586 - val_loss: 0.3561 - val_accuracy: 0.8834
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# Epoch 12/50
# 163/163 [==============================] - 373s 2s/step - loss: 0.1182 - accuracy: 0.9594 - val_loss: 0.0525 - val_accuracy: 0.8970
# Epoch 13/50
# 163/163 [==============================] - 361s 2s/step - loss: 0.1288 - accuracy: 0.9538 - val_loss: 0.1802 - val_accuracy: 0.8885
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
# Epoch 14/50
# 163/163 [==============================] - 359s 2s/step - loss: 0.1205 - accuracy: 0.9590 - val_loss: 0.3244 - val_accuracy: 0.9054
# Epoch 15/50
# 163/163 [==============================] - 360s 2s/step - loss: 0.1178 - accuracy: 0.9576 - val_loss: 0.3031 - val_accuracy: 0.8868
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 7.289999985005124e-07.
# Epoch 16/50
# 163/163 [==============================] - 359s 2s/step - loss: 0.1209 - accuracy: 0.9580 - val_loss: 0.4649 - val_accuracy: 0.8986
# Epoch 17/50
# 163/163 [==============================] - 363s 2s/step - loss: 0.1138 - accuracy: 0.9584 - val_loss: 0.3066 - val_accuracy: 0.8851
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 2.1870000637136398e-07.
# Epoch 18/50
# 163/163 [==============================] - 370s 2s/step - loss: 0.1122 - accuracy: 0.9615 - val_loss: 0.1652 - val_accuracy: 0.8919
# Epoch 19/50
# 163/163 [==============================] - 397s 2s/step - loss: 0.1279 - accuracy: 0.9569 - val_loss: 0.3566 - val_accuracy: 0.8986
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 6.561000276406048e-08.
# Epoch 20/50
# 163/163 [==============================] - 409s 3s/step - loss: 0.1171 - accuracy: 0.9592 - val_loss: 0.0434 - val_accuracy: 0.8936
# Epoch 21/50
# 163/163 [==============================] - 467s 3s/step - loss: 0.1193 - accuracy: 0.9601 - val_loss: 0.1554 - val_accuracy: 0.8931
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 1.9683000829218145e-08.
# Epoch 22/50
# 163/163 [==============================] - 495s 3s/step - loss: 0.1185 - accuracy: 0.9588 - val_loss: 0.1863 - val_accuracy: 0.8953
# Epoch 23/50
# 163/163 [==============================] - 495s 3s/step - loss: 0.1152 - accuracy: 0.9618 - val_loss: 0.2995 - val_accuracy: 0.8902
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 5.904900035602622e-09.
# Epoch 24/50
# 163/163 [==============================] - 501s 3s/step - loss: 0.1254 - accuracy: 0.9569 - val_loss: 0.4476 - val_accuracy: 0.8953
# Epoch 25/50
# 163/163 [==============================] - 488s 3s/step - loss: 0.1193 - accuracy: 0.9565 - val_loss: 0.0791 - val_accuracy: 0.8919
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 1.7714700373261393e-09.
# Epoch 26/50
# 163/163 [==============================] - 497s 3s/step - loss: 0.1260 - accuracy: 0.9563 - val_loss: 0.4877 - val_accuracy: 0.8986
# Epoch 27/50
# 163/163 [==============================] - 483s 3s/step - loss: 0.1196 - accuracy: 0.9576 - val_loss: 0.3620 - val_accuracy: 0.8986
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 5.314410245205181e-10.
# Epoch 28/50
# 163/163 [==============================] - 488s 3s/step - loss: 0.1247 - accuracy: 0.9548 - val_loss: 0.2006 - val_accuracy: 0.8902
# Epoch 29/50
# 163/163 [==============================] - 678s 4s/step - loss: 0.1245 - accuracy: 0.9572 - val_loss: 0.2108 - val_accuracy: 0.8885
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 1.5943230069481729e-10.
# Epoch 30/50
# 163/163 [==============================] - 408s 3s/step - loss: 0.1213 - accuracy: 0.9555 - val_loss: 0.3081 - val_accuracy: 0.9088
# Epoch 31/50
# 163/163 [==============================] - 421s 3s/step - loss: 0.1100 - accuracy: 0.9603 - val_loss: 0.3290 - val_accuracy: 0.8902
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 4.7829690208445185e-11.
# Epoch 32/50
# 163/163 [==============================] - 381s 2s/step - loss: 0.1186 - accuracy: 0.9580 - val_loss: 0.5109 - val_accuracy: 0.8885
# Epoch 33/50
# 163/163 [==============================] - 367s 2s/step - loss: 0.1218 - accuracy: 0.9576 - val_loss: 0.4581 - val_accuracy: 0.9003
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 1.434890747886719e-11.
# Epoch 34/50
# 163/163 [==============================] - 359s 2s/step - loss: 0.1160 - accuracy: 0.9582 - val_loss: 0.3700 - val_accuracy: 0.8868
# Epoch 35/50
# 163/163 [==============================] - 360s 2s/step - loss: 0.1188 - accuracy: 0.9590 - val_loss: 0.3369 - val_accuracy: 0.9037
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 4.304672243660157e-12.
# Epoch 36/50
# 163/163 [==============================] - 453s 3s/step - loss: 0.1146 - accuracy: 0.9632 - val_loss: 0.2605 - val_accuracy: 0.8919
# Epoch 37/50
# 163/163 [==============================] - 540s 3s/step - loss: 0.1120 - accuracy: 0.9617 - val_loss: 0.6553 - val_accuracy: 0.8936
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 1.2914016210563428e-12.
# Epoch 38/50
# 163/163 [==============================] - 385s 2s/step - loss: 0.1209 - accuracy: 0.9557 - val_loss: 0.1144 - val_accuracy: 0.8919
# Epoch 39/50
# 163/163 [==============================] - 402s 2s/step - loss: 0.1201 - accuracy: 0.9574 - val_loss: 0.5922 - val_accuracy: 0.8919
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 3.874204993273289e-13.
# Epoch 40/50
# 163/163 [==============================] - 375s 2s/step - loss: 0.1183 - accuracy: 0.9588 - val_loss: 0.2340 - val_accuracy: 0.8953
# Epoch 41/50
# 163/163 [==============================] - 422s 3s/step - loss: 0.1172 - accuracy: 0.9607 - val_loss: 0.4853 - val_accuracy: 0.8964
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 1.162261530508052e-13.
# Epoch 42/50
# 163/163 [==============================] - 406s 2s/step - loss: 0.1158 - accuracy: 0.9576 - val_loss: 0.4235 - val_accuracy: 0.8885
# Epoch 43/50
# 163/163 [==============================] - 388s 2s/step - loss: 0.1180 - accuracy: 0.9597 - val_loss: 0.3951 - val_accuracy: 0.8936
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 3.4867844288938296e-14.
# Epoch 44/50
# 163/163 [==============================] - 394s 2s/step - loss: 0.1236 - accuracy: 0.9555 - val_loss: 0.2574 - val_accuracy: 0.9037
# Epoch 45/50
# 163/163 [==============================] - 375s 2s/step - loss: 0.1181 - accuracy: 0.9595 - val_loss: 0.2244 - val_accuracy: 0.8970
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 1.0460353083393582e-14.
# Epoch 46/50
# 163/163 [==============================] - 368s 2s/step - loss: 0.1084 - accuracy: 0.9595 - val_loss: 0.1974 - val_accuracy: 0.8767
# Epoch 47/50
# 163/163 [==============================] - 397s 2s/step - loss: 0.1252 - accuracy: 0.9574 - val_loss: 0.1649 - val_accuracy: 0.8953
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 3.138105874196098e-15.
# Epoch 48/50
# 163/163 [==============================] - 514s 3s/step - loss: 0.1181 - accuracy: 0.9561 - val_loss: 0.2677 - val_accuracy: 0.8970
# Epoch 49/50
# 163/163 [==============================] - 500s 3s/step - loss: 0.1223 - accuracy: 0.9563 - val_loss: 0.2881 - val_accuracy: 0.8986
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 9.414317622588293e-16.
# Epoch 50/50
# 163/163 [==============================] - 507s 3s/step - loss: 0.1173 - accuracy: 0.9597 - val_loss: 0.5953 - val_accuracy: 0.9003

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 3))
ax = ax.ravel()

for i, met in enumerate(['accuracy', 'loss']):
    ax[i].plot(hist.history[met])
    ax[i].plot(hist.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])
